# %%
from skyview_func import call_skyview

# %%
call_skyview('M31', 'DSS', fov=2)
# Out:
# Source coordinates for M31: 10.68470833 deg 41.26875 deg
# Looking for survey DSS for source M31
# INFO: Auto-setting vmin to  2.495e+03 [aplpy.core]
# INFO: Auto-setting vmax to  1.335e+04 [aplpy.core]
# Fits file: M31_DSS_2d.fits
# png file:  M31_DSS_2d.png
